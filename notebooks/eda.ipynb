# %%
# %run ../helper_function/setup_env.py

# %%
setup_project_env()
# Out:
# Added 'c:\Users\saurabhskumar\Documents\project\Pahrma\Drug_Review_Sentiment' to Python path.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print(os.path)
# Out:
# <module 'ntpath' (frozen)>

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

print(sys.path)
# Out:
# ['c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\notebooks', 'C:\\Users\\saurabhskumar\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\saurabhskumar\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\saurabhskumar\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\saurabhskumar\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\ml_venv', '', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\ml_venv\\Lib\\site-packages', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\ml_venv\\Lib\\site-packages\\win32', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\ml_venv\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment\\ml_venv\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\saurabhskumar\\Documents\\project\\Pahrma\\Drug_Review_Sentiment']

# %%
from helper_function.tsv_reader import TSVReader
